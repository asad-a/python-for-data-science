# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src = "https://ibm.box.com/shared/static/wbqvbi6o6ip0vz55ua5gp17g4f1k7ve9.png" width = 400> </a>
#
# <h4 align ="center" style="color: #191966">Toronto Big Data University Meetup</h4>
# <h4 align ="center" style="color: #191966">Intro to Python for Data Science</h4>
#
#
# <h4 align = "center">[Instructor: Asad Ali](https://www.linkedin.com/in/asad-ali-082a613b)</h4>

# %% [markdown]
# # <span style="color: #20B2AA">Navigating the Jupyter Notebook</span>
#
# #### There are two modes:
#  - **Command Mode** allows you to navigate on the page, between cells
#  - **Edit Mode** is inside the cell. Press enter to start typing and esc to stop.
#
# #### Some short cuts:
#  - **h** for help
#  - **shift + enter** to run cell and move to the next one
#  - **ctrl + enter** to run cell and
#  - **a** inserts a cell above
#  - **b** inserts a cell below
#  - ** c, x, v **  behave like copy, cut and paste
#  - **d, d** double pressing d will delete a cell
#
#  - **shift + tab** displays the help for that particular function
#
# #### Types of cells:
#  - **code** which are cells that actually run commands
#  - **markdown** fancy formatting, notes, etc
#
# # <span style="color: #20B2AA">Python Data Types</span> #
#
# The Basics
# - **int** Integers
# - **float**  Roughly equivalent to decimal numbers
# - **string** Words or characters. They have to be enclosed within single or double quotation marks
# ```python
# name = 'Asad'
# ```
# ```python
# goal = "To always get a good night's sleep."
# ```
# - ** list [ ] **  Lists of items. These items can be ints, floats, strings, or even lists of lists. The square brackets denote that they are lists
# ```python
# my_shopping_list = ['apples', 'oranges', 'bananas']
# ```
# - **dictionary { }** a data type with key(s) and value(s) -
# ```python
# contacts = { 'Name' : 'Asad',
# 'Favourite Number' : 4,
# 'Friends' : ['Jack', 'Jill'] }
# ```

# %%
print type(3)

# %%
print type(3.0)

# %%
print type('Python')

# %%
print type(['Data', 'Scientist'])

# %%
print type({ 'Name' : 'Asad',
            'Favourite Number' : 4,
            'Friends' : ['Jack', 'Jill']})

# %% [markdown]
# # <span style="color: #20B2AA">Basic Python Operations</span> #

# %%
# Printing vs display

# %%
# Example of integers

# %%
# Example of strings

# %%
# String addition

# %%
# 10/3 vs. 10/3.0 and casting

# %%
# Create your own shopping list with three items
['bananas, apples, oranges']
# Out:
# ['bananas, apples, oranges']

# %%
# Fill in the information for the dictionary below:
{'name' : 'Asad',
 'age' : 99}
# Out:
# {'age': 99, 'name': 'Asad'}

# %%
# Assigning variables
# Use a single equals sign (=) to assign something to a variable so you can call it later
# Everything on the right hand side gets assigned to the name on the left

# %%
# Assign your list to the variable my_shopping_list
my_shopping_list = ['bananas', 'apples', 'oranges']

# %%
# Accessing items in your list using square brackets and the position of the item
# Python index/position starts at 0, not 1!

# To get the first item in the list:
print my_shopping_list[0]

# To get the third item in the list:
print my_shopping_list[2]
# Out:
# bananas
# oranges

# %%
# Add an item to a list using .append()

my_shopping_list.append('milk')
print my_shopping_list
# Out:
# ['bananas', 'apples', 'oranges', 'milk']

# %%
# Determine the length of a list using len()

len(my_shopping_list)
# Out:
# 4

# %%
# Copy the dict above, paste it below, and assign it to the variable my_dictionary
my_dictionary = {'name' : 'Asad',
                 'age' : 99}

# %%
# Access items in your dictionary using the name of the key in square brackets
my_dictionary['age']
# Out:
# 99

# %% [markdown]
# # <span style="color: #20B2AA">Logical Operators</span>
#
# #### Returns a value of True or False based on a comparison.
#
# #### Examples:
#
# ```python
# == equal to
# != not equal to
# <  less than
# >  greater than
# <= less than or equal to
# >= greater than or equal to
#
#     'a' == 'a' will evaluate to True
#     4 != 4     will evaluate to False
#     3 < 8      will evaluate to True
#     10 > 1     will evaluate to True
#     1 <= 1     will evaluate to True
#     5 >= 9     will evaluate to False
# ```
#
# [A useful resource can be found here](http://www.tutorialspoint.com/python/python_basic_operators.htm)

# %%
# Try some operations here to get a feel for these

# %% [markdown]
# # <span style="color: #20B2AA">If Statments, Loops and Functions</span> #

# %%
# See if the sum of two integers is = 10
# If it is, print 'Yay!'
# Else, If it is equal to 9, print 'Not quite!'
# Else, print 'Nay!'

int1 = 4
int2 = 5

if ((int1 + int2) == 10):
    print 'Yay!'
elif ((int1 + int2) == 9):
    print 'Not quite!'
else:
    print 'Nay!'
# Out:
# Not quite!

# %%
# This loops through each item in 'my_shopping_list' and prints each item.

for each_item in my_shopping_list:
    
    print each_item
    
# Now let's print each item + ' - Bought!'

for each_item in my_shopping_list:
    
    print each_item + ' - Bought!'
# Out:
# bananas
# apples
# oranges
# milk
# bananas - Bought!
# apples - Bought!
# oranges - Bought!
# milk - Bought!

# %%
# Create a tip calculator function
# Step 1: Take two inputs. The total before tax, and the amount you want to tip.
# Step 2: Calculate the tip amount and save it to tip_amount
# Step 3: Calculate the new total and return the new total.

def tip_calculator(total_before_tip, tip_percentage):
    
    tip_percentage_float = tip_percentage / 100.0 #Note the 100.0 to ensure it gets a decimal place! 
    tip_amount = tip_percentage_float * total_before_tip
    new_total = total_before_tip + tip_amount
    
    return new_total
    
#This is how you call a function
print tip_calculator(100, 15)

# An example of how we would use this function:
'Your new total is ' + str(tip_calculator(100,15)) + ' Dollars.'
# Out:
# 115.0
# 'Your new total is 115.0 Dollars.'

# %% [markdown]
# ---
#
# # <span style="color: #20B2AA">Let Us Know When You're Done</span>
#
# <a href="https://twitter.com/intent/tweet?screen_name=bigdatau&text=Making%20Visualizations%20and%20Learning%20Python%20for%20Data%20Science%20with%20asad_ali_47.%20%23bdumeetup%20%23datascience%20http%3A%2F%2Fi.imgur.com%2Fur2o0ZU.png" target="_blank">
#         <img src="http://i.imgur.com/sUNC7ax.png" width=640></a>
#
# ---

# %% [markdown]
# # <span style="color: #20B2AA">Today's Task:</span> #
#
#
# [We are going to try and recreate the graph below of olympic athletes' heights and weights](http://www.bbc.com/news/uk-19050139)
#
# <img src = http://i.imgur.com/AALRdVr.png width=640>

# %% [markdown]
# # <span style="color: #20B2AA">Creating the scatter plot in 18 lines</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline 

df = pd.read_csv('https://drive.google.com/uc?export=download&id=0B0lqdhFbaTQ-T3E4VDlHUDFuWVU')

df.gender = df.gender.fillna('M')
df.country_code = df.country_code.fillna('USA')
df.first_name = df.first_name.fillna('Fabiana')

df.plot(kind='scatter',
        x='weight_kg',
        y='height_cm',
        title='Your Olympic Athlete Body Match',
        marker='s',
        color='orange',
        figsize=(14,8))
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# # <span style="color: #20B2AA">Step 1: Create Data</span>

# %%
# This import statement is how we ensure that pandas methods are available to us
import pandas as pd

# matplotlib is a plotting/graphing library
import matplotlib.pyplot as plt
# this is the style of plot that we want to use
plt.style.use('ggplot')

# This gives permission to draw diagrams in our notebook
# %matplotlib inline

# %%
# The first step will be to create our own athlete


# This dictionary called my_athlete will store all the information that we need
# Replace my information with anything you like!
my_athlete = {'last_name': 'Ali',
              'first_name': 'Asad',
              'height_cm': 175.0,
              'weight_kg': 82.0,
              'country': 'Zambia',
              'country_code': 'ZMB', #CAN for Canada
              'gender': 'M',
              'sport': 'Archery', 
              'event': "Men's Individual"}

my_athlete
# Out:
# {'country': 'Zambia',
#  'country_code': 'ZMB',
#  'event': "Men's Individual",
#  'first_name': 'Asad',
#  'gender': 'M',
#  'height_cm': 175.0,
#  'last_name': 'Ali',
#  'sport': 'Archery',
#  'weight_kg': 82.0}

# %% [markdown]
# <span style="color: #FD2E33">Now we can use a very convenient method called [.DataFrame( )](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) to create a DataFrame using our data</span>
#
# >```python
# pd.DataFrame(data=my_athlete, index=[index])
# ```

# %%
pd.DataFrame(my_athlete, index=[0])
# Out:
#   country country_code             event first_name gender  height_cm  \
# 0  Zambia          ZMB  Men's Individual       Asad      M        175
#
#   last_name    sport  weight_kg
# 0       Ali  Archery         82

# %% [markdown]
# # <span style="color: #20B2AA">Step 2: Read in the Rest of the Data</span>
#
# <img src = "http://i.imgur.com/uJDPJuc.jpg" width=640>
#
# <h4 align="center" style="color: #FD2E33">We use a method called [read_csv()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html). This is the most common format for data and most people have used csv files at some point in Excel. The read_csv method takes this file and turns it into a dataframe.</h4>
#
# <h4 align="center"> [You can download the .csv file here](https://drive.google.com/file/d/0B0lqdhFbaTQ-T3E4VDlHUDFuWVU/view?usp=sharing)</h4>
#
# <img src= "http://i.imgur.com/OumfCEQ.png", width=640>
#
# <h4 align="center" style="color: #FD2E33">
# Once you've downloaded the file, just drag it in to this window to upload it to your DSWB account.</h4>
#
# ---

# %%
# Please upload the messy data file from github.com/asad-a, navigate to Python for Data Science.
# And then upload it to data scientist workbench
df = pd.read_csv('/resources/messy_data.csv')

# In case the file isn't working, you can also read it directly from this url:
#df = pd.read_csv('https://drive.google.com/uc?export=download&id=0B0lqdhFbaTQ-T3E4VDlHUDFuWVU')

df
# Out:
#           last_name        first_name  height_cm  weight_kg  \
# 0             Pipes               Ben        204         90
# 1         Bolshakov            Sergey        190         90
# 2        Niyomugabo           Jackson        184         71
# 3         Palameika            Madara        183         76
# 4           Sibello        Gianfranco        188         84
# 5           Kulkina              Anna        167         52
# 6         Degtyarev              Egor        202         96
# 7            Garcia  Fernando Gabriel        190         85
# 8            Kynard              Erik        193         86
# 9         Taouerghi            Anouer        178         77
# 10         O'KEEFFE           Michael        183         78
# 11        Cheverton          Samantha        160         48
# 12           Takano               Aya        164         54
# 13            Sakai            Hiroki        183         70
# 14          Eastham             Casey        170         62
# 15          Yushkov              Ivan        192        130
# 16           Kalmer              Rene        178         49
# 17        Hladikova             Aneta        171         62
# 18       Bernardova              Sona        168         55
# 19    Tenorio Silva              Rosa        163         69
# 20         Campazzo           Facundo        179         88
# 21          Ghayaza           Mokhtar        205        106
# 22            Lucas            Dakota        170         68
# 23           Mullin            Shauna        178         74
# 24          Wiersum             Peter        173         55
# 25           Duenas           Crispin        170         81
# 26         Yamamoto             Kohei        182         69
# 27     Kvyatkovskyy            Andriy        173         71
# 28           Tejeda            Gladys        162         46
# 29        Aranowski          Krystian        198        100
# ...             ...               ...        ...        ...
# 1556          Satch              Will        194         94
# 1557       Willmott             Aimee        172         56
# 1558         Waller              Jack        187         95
# 1559       Robinson              Glen        188         90
# 1560      Honeybone             James        192         81
# 1561           Foad             James        185         90
# 1562          Reade           Shanaze        170         76
# 1563       Gladding           Monique        162         57
# 1564         Austin             James        188        100
# 1565          White             Ellen        170         58
# 1566         Vernon             Annie        178         75
# 1567       Loughran             Marco        186         75
# 1568         Knobbs          Jennifer        155         49
# 1569        Johnson              Kyle        194         93
# 1570           Webb             David        178         62
# 1571       Mccarthy      McCARTHY Ale        193         88
# 1572       Williams               Rob        185         75
# 1573       Chambers           Richard        183         74
# 1574        Godfrey             Larry        178         84
# 1575       Marshall          Savannah        181         75
# 1576          Okoro           Marilyn        167         60
# 1577         Pooley              Emma        157         48
# 1578           Ling                Ed        178         76
# 1579         Pinner            George        193         93
# 1580         Bakare             Peter        196         93
# 1581      Dobriskey              Lisa        171         56
# 1582        Goodwin             Britt        163         68
# 1583          Zhang            Zhaoxu        219        110
# 1584        Blas Jr           Ricardo        185        218
# 1585       Teramoto             Asuka        136         30
#
#                       country country_code gender                    sport  \
# 0                     Team GB          GBR    NaN               Volleyball
# 1          Russian Federation          RUS    NaN                 Swimming
# 2                      Rwanda          RWA    NaN                 Swimming
# 3                      Latvia          LAT      F                Athletics
# 4                       Italy          ITA    NaN                  Sailing
# 5                  Kazakhstan          KAZ      F    Synchronised Swimming
# 6          Russian Federation          RUS    NaN                 Swimming
# 7                   Argentina          ARG    NaN                 Handball
# 8                    Team USA          NaN    NaN                Athletics
# 9                     Tunisia          TUN    NaN               Volleyball
# 10                New Zealand          NZL    NaN                 Football
# 11                     Canada          CAN      F                 Swimming
# 12                      Japan          JPN      F                 Swimming
# 13                      Japan          JPN    NaN                 Football
# 14    Australian Olympic Team          AUS      F                   Hockey
# 15         Russian Federation          RUS    NaN                Athletics
# 16               South Africa          RSA      F                Athletics
# 17             Czech Republic          CZE      F            Cycling - BMX
# 18             Czech Republic          CZE      F    Synchronised Swimming
# 19                    Ecuador          ECU      F            Weightlifting
# 20                  Argentina          ARG    NaN               Basketball
# 21                    Tunisia          TUN    NaN               Basketball
# 22                New Zealand          NZL    NaN                 Football
# 23                    Team GB          GBR      F         Beach Volleyball
# 24                Netherlands          NED    NaN                   Rowing
# 25                     Canada          CAN    NaN                  Archery
# 26                      Japan          JPN    NaN  Cycling - Mountain Bike
# 27                    Ukraine          UKR    NaN                Wrestling
# 28                       Peru          PER      F                Athletics
# 29                     Poland          POL    NaN                   Rowing
# ...                       ...          ...    ...                      ...
# 1556                  Team GB          GBR    NaN                   Rowing
# 1557                  Team GB          GBR      F                 Swimming
# 1558                  Team GB          GBR    NaN               Water Polo
# 1559                  Team GB          GBR    NaN               Water Polo
# 1560                  Team GB          GBR    NaN                  Fencing
# 1561                  Team GB          GBR    NaN                   Rowing
# 1562                  Team GB          GBR      F            Cycling - BMX
# 1563                  Team GB          GBR      F                   Diving
# 1564                  Team GB          GBR    NaN                     Judo
# 1565                  Team GB          GBR      F                 Football
# 1566                  Team GB          GBR      F                   Rowing
# 1567                  Team GB          GBR    NaN                 Swimming
# 1568                  Team GB          GBR      F    Synchronised Swimming
# 1569                  Team GB          GBR    NaN               Basketball
# 1570                  Team GB          GBR    NaN                Athletics
# 1571                  Team GB          GBR    NaN                 Football
# 1572                  Team GB          GBR    NaN                   Rowing
# 1573                  Team GB          GBR    NaN                   Rowing
# 1574                  Team GB          GBR    NaN                  Archery
# 1575                  Team GB          GBR      F                   Boxing
# 1576                  Team GB          GBR      F                Athletics
# 1577                  Team GB          GBR      F           Cycling - Road
# 1578                  Team GB          GBR    NaN                 Shooting
# 1579                  Team GB          GBR    NaN                   Hockey
# 1580                  Team GB          GBR    NaN               Volleyball
# 1581                  Team GB          GBR      F                Athletics
# 1582                  Team GB          GBR      F                 Handball
# 1583                    China          CHN    NaN               Basketball
# 1584                     Guam          GUM    NaN                     Judo
# 1585                    Japan          JPN      F    Gymnastics - Artistic
#
#                                  event
# 0                     Men's Volleyball
# 1                  Men's Marathon 10km
# 2                  Men's 50m Freestyle
# 3                Women's Javelin Throw
# 4                           Men's 49er
# 5                        Women's Duets
# 6                 Men's 400m Freestyle
# 7                       Men's Handball
# 8                      Men's High Jump
# 9                     Men's Volleyball
# 10                      Men's Football
# 11              Women's 200m Freestyle
# 12    Women's 4 x 200m Freestyle Relay
# 13                      Men's Football
# 14                      Women's Hockey
# 15                      Men's Shot Put
# 16                    Women's Marathon
# 17                         Women's BMX
# 18                       Women's Duets
# 19                        Women's 69kg
# 20                    Men's Basketball
# 21                    Men's Basketball
# 22                      Men's Football
# 23            Women's Beach Volleyball
# 24                         Men's Eight
# 25                    Men's Individual
# 26                 Men's Mountain Bike
# 27                Men's Freestyle 66kg
# 28                    Women's Marathon
# 29                         Men's Eight
# ...                                ...
# 1556                        Men's Pair
# 1557    Women's 400m Individual Medley
# 1558                  Men's Water Polo
# 1559                  Men's Water Polo
# 1560            Men's Individual Sabre
# 1561                       Men's Eight
# 1562                       Women's BMX
# 1563              Women's 10m Platform
# 1564                      Men's -100kg
# 1565                  Women's Football
# 1566                     Women's Eight
# 1567             Men's 200m Backstroke
# 1568                     Women's Teams
# 1569                  Men's Basketball
# 1570                    Men's Marathon
# 1571                    Men's Football
# 1572            Men's Lightweight Four
# 1573            Men's Lightweight Four
# 1574                  Men's Individual
# 1575       Women's Middleweight (75kg)
# 1576            Women's 4 x 400m Relay
# 1577     Women's Individual Time Trial
# 1578                        Men's Trap
# 1579                      Men's Hockey
# 1580                  Men's Volleyball
# 1581                     Women's 1500m
# 1582                  Women's Handball
# 1583                  Men's Basketball
# 1584                      Men's +100kg
# 1585            Women's Qualifications
#
# [1586 rows x 9 columns]

# %%
df.shape
# Out:
# (1586, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1586 entries, 0 to 1585
# Data columns (total 9 columns):
# last_name       1586 non-null object
# first_name      1585 non-null object
# height_cm       1586 non-null float64
# weight_kg       1586 non-null float64
# country         1586 non-null object
# country_code    1534 non-null object
# gender          717 non-null object
# sport           1586 non-null object
# event           1586 non-null object
# dtypes: float64(2), object(7)
# memory usage: 123.9+ KB

# %%
df.describe()
# Out:
#          height_cm    weight_kg
# count  1586.000000  1586.000000
# mean    177.454603    72.656999
# std      11.290409    16.014256
# min     136.000000    30.000000
# 25%     170.000000    61.000000
# 50%     177.000000    70.000000
# 75%     185.000000    81.000000
# max     219.000000   218.000000

# %%
# Read the first few rows of the data. Enter a number between the parentheses to adjust
df.head()
# Out:
#     last_name  first_name  height_cm  weight_kg             country  \
# 0       Pipes         Ben        204         90             Team GB
# 1   Bolshakov      Sergey        190         90  Russian Federation
# 2  Niyomugabo     Jackson        184         71              Rwanda
# 3   Palameika      Madara        183         76              Latvia
# 4     Sibello  Gianfranco        188         84               Italy
#
#   country_code gender       sport                  event
# 0          GBR    NaN  Volleyball       Men's Volleyball
# 1          RUS    NaN    Swimming    Men's Marathon 10km
# 2          RWA    NaN    Swimming    Men's 50m Freestyle
# 3          LAT      F   Athletics  Women's Javelin Throw
# 4          ITA    NaN     Sailing             Men's 49er

# %%
# Read the last few rows of the data. Enter a number between the parentheses to adjust
df.tail()
# Out:
#       last_name first_name  height_cm  weight_kg  country country_code gender  \
# 1581  Dobriskey       Lisa        171         56  Team GB          GBR      F
# 1582    Goodwin      Britt        163         68  Team GB          GBR      F
# 1583      Zhang     Zhaoxu        219        110    China          CHN    NaN
# 1584    Blas Jr    Ricardo        185        218     Guam          GUM    NaN
# 1585   Teramoto      Asuka        136         30    Japan          JPN      F
#
#                       sport                   event
# 1581              Athletics           Women's 1500m
# 1582               Handball        Women's Handball
# 1583             Basketball        Men's Basketball
# 1584                   Judo            Men's +100kg
# 1585  Gymnastics - Artistic  Women's Qualifications

# %%
# Using the .append() function, let's add our athlete from above
df.append(my_athlete, ignore_index=True)
# Out:
#           last_name        first_name  height_cm  weight_kg  \
# 0             Pipes               Ben        204         90
# 1         Bolshakov            Sergey        190         90
# 2        Niyomugabo           Jackson        184         71
# 3         Palameika            Madara        183         76
# 4           Sibello        Gianfranco        188         84
# 5           Kulkina              Anna        167         52
# 6         Degtyarev              Egor        202         96
# 7            Garcia  Fernando Gabriel        190         85
# 8            Kynard              Erik        193         86
# 9         Taouerghi            Anouer        178         77
# 10         O'KEEFFE           Michael        183         78
# 11        Cheverton          Samantha        160         48
# 12           Takano               Aya        164         54
# 13            Sakai            Hiroki        183         70
# 14          Eastham             Casey        170         62
# 15          Yushkov              Ivan        192        130
# 16           Kalmer              Rene        178         49
# 17        Hladikova             Aneta        171         62
# 18       Bernardova              Sona        168         55
# 19    Tenorio Silva              Rosa        163         69
# 20         Campazzo           Facundo        179         88
# 21          Ghayaza           Mokhtar        205        106
# 22            Lucas            Dakota        170         68
# 23           Mullin            Shauna        178         74
# 24          Wiersum             Peter        173         55
# 25           Duenas           Crispin        170         81
# 26         Yamamoto             Kohei        182         69
# 27     Kvyatkovskyy            Andriy        173         71
# 28           Tejeda            Gladys        162         46
# 29        Aranowski          Krystian        198        100
# ...             ...               ...        ...        ...
# 1557       Willmott             Aimee        172         56
# 1558         Waller              Jack        187         95
# 1559       Robinson              Glen        188         90
# 1560      Honeybone             James        192         81
# 1561           Foad             James        185         90
# 1562          Reade           Shanaze        170         76
# 1563       Gladding           Monique        162         57
# 1564         Austin             James        188        100
# 1565          White             Ellen        170         58
# 1566         Vernon             Annie        178         75
# 1567       Loughran             Marco        186         75
# 1568         Knobbs          Jennifer        155         49
# 1569        Johnson              Kyle        194         93
# 1570           Webb             David        178         62
# 1571       Mccarthy      McCARTHY Ale        193         88
# 1572       Williams               Rob        185         75
# 1573       Chambers           Richard        183         74
# 1574        Godfrey             Larry        178         84
# 1575       Marshall          Savannah        181         75
# 1576          Okoro           Marilyn        167         60
# 1577         Pooley              Emma        157         48
# 1578           Ling                Ed        178         76
# 1579         Pinner            George        193         93
# 1580         Bakare             Peter        196         93
# 1581      Dobriskey              Lisa        171         56
# 1582        Goodwin             Britt        163         68
# 1583          Zhang            Zhaoxu        219        110
# 1584        Blas Jr           Ricardo        185        218
# 1585       Teramoto             Asuka        136         30
# 1586            Ali              Asad        175         82
#
#                       country country_code gender                    sport  \
# 0                     Team GB          GBR    NaN               Volleyball
# 1          Russian Federation          RUS    NaN                 Swimming
# 2                      Rwanda          RWA    NaN                 Swimming
# 3                      Latvia          LAT      F                Athletics
# 4                       Italy          ITA    NaN                  Sailing
# 5                  Kazakhstan          KAZ      F    Synchronised Swimming
# 6          Russian Federation          RUS    NaN                 Swimming
# 7                   Argentina          ARG    NaN                 Handball
# 8                    Team USA          NaN    NaN                Athletics
# 9                     Tunisia          TUN    NaN               Volleyball
# 10                New Zealand          NZL    NaN                 Football
# 11                     Canada          CAN      F                 Swimming
# 12                      Japan          JPN      F                 Swimming
# 13                      Japan          JPN    NaN                 Football
# 14    Australian Olympic Team          AUS      F                   Hockey
# 15         Russian Federation          RUS    NaN                Athletics
# 16               South Africa          RSA      F                Athletics
# 17             Czech Republic          CZE      F            Cycling - BMX
# 18             Czech Republic          CZE      F    Synchronised Swimming
# 19                    Ecuador          ECU      F            Weightlifting
# 20                  Argentina          ARG    NaN               Basketball
# 21                    Tunisia          TUN    NaN               Basketball
# 22                New Zealand          NZL    NaN                 Football
# 23                    Team GB          GBR      F         Beach Volleyball
# 24                Netherlands          NED    NaN                   Rowing
# 25                     Canada          CAN    NaN                  Archery
# 26                      Japan          JPN    NaN  Cycling - Mountain Bike
# 27                    Ukraine          UKR    NaN                Wrestling
# 28                       Peru          PER      F                Athletics
# 29                     Poland          POL    NaN                   Rowing
# ...                       ...          ...    ...                      ...
# 1557                  Team GB          GBR      F                 Swimming
# 1558                  Team GB          GBR    NaN               Water Polo
# 1559                  Team GB          GBR    NaN               Water Polo
# 1560                  Team GB          GBR    NaN                  Fencing
# 1561                  Team GB          GBR    NaN                   Rowing
# 1562                  Team GB          GBR      F            Cycling - BMX
# 1563                  Team GB          GBR      F                   Diving
# 1564                  Team GB          GBR    NaN                     Judo
# 1565                  Team GB          GBR      F                 Football
# 1566                  Team GB          GBR      F                   Rowing
# 1567                  Team GB          GBR    NaN                 Swimming
# 1568                  Team GB          GBR      F    Synchronised Swimming
# 1569                  Team GB          GBR    NaN               Basketball
# 1570                  Team GB          GBR    NaN                Athletics
# 1571                  Team GB          GBR    NaN                 Football
# 1572                  Team GB          GBR    NaN                   Rowing
# 1573                  Team GB          GBR    NaN                   Rowing
# 1574                  Team GB          GBR    NaN                  Archery
# 1575                  Team GB          GBR      F                   Boxing
# 1576                  Team GB          GBR      F                Athletics
# 1577                  Team GB          GBR      F           Cycling - Road
# 1578                  Team GB          GBR    NaN                 Shooting
# 1579                  Team GB          GBR    NaN                   Hockey
# 1580                  Team GB          GBR    NaN               Volleyball
# 1581                  Team GB          GBR      F                Athletics
# 1582                  Team GB          GBR      F                 Handball
# 1583                    China          CHN    NaN               Basketball
# 1584                     Guam          GUM    NaN                     Judo
# 1585                    Japan          JPN      F    Gymnastics - Artistic
# 1586                   Zambia          ZMB      M                  Archery
#
#                                  event
# 0                     Men's Volleyball
# 1                  Men's Marathon 10km
# 2                  Men's 50m Freestyle
# 3                Women's Javelin Throw
# 4                           Men's 49er
# 5                        Women's Duets
# 6                 Men's 400m Freestyle
# 7                       Men's Handball
# 8                      Men's High Jump
# 9                     Men's Volleyball
# 10                      Men's Football
# 11              Women's 200m Freestyle
# 12    Women's 4 x 200m Freestyle Relay
# 13                      Men's Football
# 14                      Women's Hockey
# 15                      Men's Shot Put
# 16                    Women's Marathon
# 17                         Women's BMX
# 18                       Women's Duets
# 19                        Women's 69kg
# 20                    Men's Basketball
# 21                    Men's Basketball
# 22                      Men's Football
# 23            Women's Beach Volleyball
# 24                         Men's Eight
# 25                    Men's Individual
# 26                 Men's Mountain Bike
# 27                Men's Freestyle 66kg
# 28                    Women's Marathon
# 29                         Men's Eight
# ...                                ...
# 1557    Women's 400m Individual Medley
# 1558                  Men's Water Polo
# 1559                  Men's Water Polo
# 1560            Men's Individual Sabre
# 1561                       Men's Eight
# 1562                       Women's BMX
# 1563              Women's 10m Platform
# 1564                      Men's -100kg
# 1565                  Women's Football
# 1566                     Women's Eight
# 1567             Men's 200m Backstroke
# 1568                     Women's Teams
# 1569                  Men's Basketball
# 1570                    Men's Marathon
# 1571                    Men's Football
# 1572            Men's Lightweight Four
# 1573            Men's Lightweight Four
# 1574                  Men's Individual
# 1575       Women's Middleweight (75kg)
# 1576            Women's 4 x 400m Relay
# 1577     Women's Individual Time Trial
# 1578                        Men's Trap
# 1579                      Men's Hockey
# 1580                  Men's Volleyball
# 1581                     Women's 1500m
# 1582                  Women's Handball
# 1583                  Men's Basketball
# 1584                      Men's +100kg
# 1585            Women's Qualifications
# 1586                  Men's Individual
#
# [1587 rows x 9 columns]

# %%
# Whoops! Where did my_athlete go?
df.tail()
# Out:
#       last_name first_name  height_cm  weight_kg  country country_code gender  \
# 1581  Dobriskey       Lisa        171         56  Team GB          GBR      F
# 1582    Goodwin      Britt        163         68  Team GB          GBR      F
# 1583      Zhang     Zhaoxu        219        110    China          CHN    NaN
# 1584    Blas Jr    Ricardo        185        218     Guam          GUM    NaN
# 1585   Teramoto      Asuka        136         30    Japan          JPN      F
#
#                       sport                   event
# 1581              Athletics           Women's 1500m
# 1582               Handball        Women's Handball
# 1583             Basketball        Men's Basketball
# 1584                   Judo            Men's +100kg
# 1585  Gymnastics - Artistic  Women's Qualifications

# %%
# Remember to save the appended DataFrame to df
df = df.append(my_athlete, ignore_index=True)

# %%
# Now, my_athlete should appear as the final row
df.tail()
# Out:
#      last_name first_name  height_cm  weight_kg  country country_code gender  \
# 1582   Goodwin      Britt        163         68  Team GB          GBR      F
# 1583     Zhang     Zhaoxu        219        110    China          CHN    NaN
# 1584   Blas Jr    Ricardo        185        218     Guam          GUM    NaN
# 1585  Teramoto      Asuka        136         30    Japan          JPN      F
# 1586       Ali       Asad        175         82   Zambia          ZMB      M
#
#                       sport                   event
# 1582               Handball        Women's Handball
# 1583             Basketball        Men's Basketball
# 1584                   Judo            Men's +100kg
# 1585  Gymnastics - Artistic  Women's Qualifications
# 1586                Archery        Men's Individual

# %%
# Another powerful function built in to identify all unique values
df.sport.unique()
# Out:
# array(['Volleyball', 'Swimming', 'Athletics', 'Sailing',
#        'Synchronised Swimming', 'Handball', 'Football', 'Hockey',
#        'Cycling - BMX', 'Weightlifting', 'Basketball', 'Beach Volleyball',
#        'Rowing', 'Archery', 'Cycling - Mountain Bike', 'Wrestling',
#        'Diving', 'Shooting', 'Fencing', 'Table Tennis', 'Judo', 'Tennis',
#        'Badminton', 'Water Polo', 'Triathlon', 'Cycling - Road',
#        'Gymnastics - Trampoline', 'Equestrian', 'Boxing', 'Canoe Slalom',
#        'Taekwondo', 'Modern Pentathlon', 'Cycling - Track',
#        'Gymnastics - Artistic', 'Canoe Sprint', 'Gymnastics - Rhythmic'], dtype=object)

# %%
# Count up how many of each label
df.gender.value_counts()
# Out:
# F    717
# M      1
# Name: gender, dtype: int64

# %% [markdown]
# # <span style="color: #20B2AA">Step 3: How to Sort</span>
#
# ### Sort using [.sort_values( )](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html)
# ```python
# df.sort_values(by='column_name') to sort by a single column
# ```
# > The default sort order is ascending (smallest to largest)
#
# ```python
# df.sort_values(by='column', ascending=False)
# ```
# > This will sort from largest to smallest
#
# ```python
# df.sort_values(by=['column1', 'column2'], ascending=[True,True])
# ```
# > To sort by multiple columns

# %%
# Sort by last name, in ascending order
df.sort_values(by='last_name')
# Out:
#           last_name        first_name  height_cm  weight_kg  \
# 142        AL-ATHBA            Rashid        180        104
# 959       AL-HARTHI   Barakat Mubarak        171         67
# 1030  ALLEYNE-FORTE               Ade        180         73
# 1050         Abbadi             Ilyas        170         69
# 616          Abbate            Simona        171         64
# 140        Abdelaal            Hesham        167         52
# 738     Abdulrahman              Amer        168         68
# 218           Abian             Pablo        177         78
# 470        Abrantes           Arnaldo        184         78
# 1047          Abril             Erika        158         47
# 1027        Abshero             Ayele        168         62
# 278       Abu Drais           Methkal        168         62
# 1343         Achara            Kieron        208        110
# 927          Achour      Dallal Merwa        176         45
# 388            Adam           Idrissa        178         79
# 542           Adams           Lyukman        194         87
# 1315          Adams            Nicola        164         51
# 36            Adams           Antoine        180         79
# 1287         Adcock             Chris        183         80
# 1469         Adeoye          Margaret        162         65
# 1357      Adlington           Rebecca        179         70
# 153      Afroudakis          Georgios        194        103
# 623      Agamennoni              Luca        188         96
# 756       Agrafioti              Anna        178         76
# 320         Ahamada              Feta        160         50
# 1016          Ahmed  Abdou Omar Abdou        172         66
# 1048           Ahye      Michelle-Lee        160         64
# 266       Aidietyte           Neringa        177         61
# 1218        Ainslie               Ben        183         90
# 595          Akrout           Youssef        180         78
# ...             ...               ...        ...        ...
# 1544         Yankey            Rachel        164         56
# 156            Yano             Kyoko        165         60
# 107      Yaroshchuk             Hanna        176         57
# 795          Yazawa            Kazuki        167         65
# 402        Yeremyan             Arman        185         80
# 360             Yim          Junghyun        182         66
# 667           Young            Alison        181         67
# 1077         Yousif             Rabah        184         71
# 886              Yu         Peng Kean        176         65
# 668       Yurkovich            Rachel        180         70
# 737      Yushchanka           Yulyana        174         63
# 15          Yushkov              Ivan        192        130
# 904    Zabelinskaya              Olga        175         61
# 253          Zaiser              Lisa        174         63
# 381         Zaitsev        Kostiantyn        193         91
# 769          Zeller           Philipp        184         81
# 272          Zetlin             Julie        168         54
# 32           Zevina            Daryna        182         64
# 869        Zhakypov           Birzhan        167         49
# 222           Zhang            Guowei        200         77
# 1583          Zhang            Zhaoxu        219        110
# 536           Zhang               Jun        186        120
# 94             Zhao            Yudiao        174         70
# 358    Zhexembinova           Aigerim        164         47
# 960            Zhou           Chunxiu        162         48
# 476            Zhou              Peng        183         88
# 1093       Zlokovic             Boris        197        100
# 742          Zolnir             Urska        173         63
# 768           Zoric           Milenko        179         73
# 699           Zugaj             Nenad        177         84
#
#                     country country_code gender                  sport  \
# 142                   Qatar          QAT    NaN               Shooting
# 959                    Oman          OMA    NaN              Athletics
# 1030    Trinidad and Tobago          TRI    NaN              Athletics
# 1050                Algeria          ALG    NaN                 Boxing
# 616                   Italy          ITA      F             Water Polo
# 140                   Egypt          EGY    NaN                 Boxing
# 738    United Arab Emirates          UAE    NaN               Football
# 218                   Spain          ESP    NaN              Badminton
# 470                Portugal          POR    NaN              Athletics
# 1047               Colombia          COL      F              Athletics
# 1027               Ethiopia          ETH    NaN              Athletics
# 278                  Jordan          JOR    NaN              Athletics
# 1343                Team GB          GBR    NaN             Basketball
# 927                 Algeria          ALG      F             Volleyball
# 388                Cameroon          CMR    NaN              Athletics
# 542      Russian Federation          RUS    NaN              Athletics
# 1315                Team GB          GBR      F                 Boxing
# 36    Saint Kitts and Nevis          SKN    NaN              Athletics
# 1287                Team GB          GBR    NaN              Badminton
# 1469                Team GB          GBR      F              Athletics
# 1357                Team GB          GBR      F               Swimming
# 153                  Greece          GRE    NaN             Water Polo
# 623                   Italy          ITA    NaN                 Rowing
# 756                  Greece          GRE      F                Sailing
# 320                 Comoros          COM      F              Athletics
# 1016                  Egypt          EGY    NaN              Wrestling
# 1048    Trinidad and Tobago          TRI      F              Athletics
# 266               Lithuania          LTU      F              Athletics
# 1218                Team GB          GBR    NaN                Sailing
# 595                 Tunisia          TUN    NaN                Sailing
# ...                     ...          ...    ...                    ...
# 1544                Team GB          GBR      F               Football
# 156                   Japan          JPN      F               Football
# 107                 Ukraine          UKR      F              Athletics
# 795                   Japan          JPN    NaN           Canoe Slalom
# 402                 Armenia          ARM    NaN              Taekwondo
# 360             South Korea          KOR    NaN              Athletics
# 667                 Team GB          GBR      F                Sailing
# 1077                  Sudan          SUD    NaN              Athletics
# 886                Malaysia          MAS    NaN                Fencing
# 668                Team USA          NaN      F              Athletics
# 737                 Belarus          BLR      F              Athletics
# 15       Russian Federation          RUS    NaN              Athletics
# 904      Russian Federation          RUS      F         Cycling - Road
# 253                 Austria          AUT      F               Swimming
# 381                 Ukraine          UKR    NaN                 Rowing
# 769                 Germany          GER    NaN                 Hockey
# 272                Team USA          NaN      F  Gymnastics - Rhythmic
# 32                  Ukraine          UKR      F               Swimming
# 869              Kazakhstan          KAZ    NaN                 Boxing
# 222                   China          CHN    NaN              Athletics
# 1583                  China          CHN    NaN             Basketball
# 536                   China          CHN    NaN              Athletics
# 94                    China          CHN      F                 Hockey
# 358              Kazakhstan          KAZ      F  Synchronised Swimming
# 960                   China          CHN      F              Athletics
# 476                   China          CHN    NaN           Canoe Sprint
# 1093             Montenegro          MNE    NaN             Water Polo
# 742                Slovenia          SLO      F                   Judo
# 768                  Serbia          SRB    NaN           Canoe Sprint
# 699                 Croatia          CRO    NaN              Wrestling
#
#                                  event
# 142                         Men's Trap
# 959                         Men's 100m
# 1030              Men's 4 x 400m Relay
# 1050         Men's Welterweight (69kg)
# 616                 Women's Water Polo
# 140             Men's Flyweight (52kg)
# 738                     Men's Football
# 218                      Men's Singles
# 470                         Men's 200m
# 1047                  Women's Marathon
# 1027                    Men's Marathon
# 278                     Men's Marathon
# 1343                  Men's Basketball
# 927                 Women's Volleyball
# 388                         Men's 100m
# 542                  Men's Triple Jump
# 1315          Women's Flyweight (51kg)
# 36                          Men's 200m
# 1287                     Mixed Doubles
# 1469                      Women's 200m
# 1357            Women's 800m Freestyle
# 153                   Men's Water Polo
# 623                         Men's Four
# 756               Women's Laser Radial
# 320                       Women's 100m
# 1016              Men's Freestyle 66kg
# 1048                      Women's 100m
# 266                  Women's 20km Walk
# 1218                        Men's Finn
# 595                        Men's Laser
# ...                                ...
# 1544                  Women's Football
# 156                   Women's Football
# 107               Women's 400m Hurdles
# 795            Men's Kayak Single (K1)
# 402                        Men's -80kg
# 360                    Men's 50km Walk
# 667               Women's Laser Radial
# 1077                        Men's 400m
# 886             Men's Individual Sabre
# 668              Women's Javelin Throw
# 737             Women's 4 x 400m Relay
# 15                      Men's Shot Put
# 904      Women's Individual Time Trial
# 253     Women's 200m Individual Medley
# 381             Men's Quadruple Sculls
# 769                       Men's Hockey
# 272      Women's Individual All-Around
# 32    Women's 4 x 200m Freestyle Relay
# 869       Men's Light Flyweight (49kg)
# 222                    Men's High Jump
# 1583                  Men's Basketball
# 536                     Men's Shot Put
# 94                      Women's Hockey
# 358                      Women's Duets
# 960                   Women's Marathon
# 476        Men's Kayak Four (K4) 1000m
# 1093                  Men's Water Polo
# 742                      Women's -63kg
# 768        Men's Kayak Four (K4) 1000m
# 699             Men's Greco-Roman 84kg
#
# [1587 rows x 9 columns]

# %%
# Sort by last name in ascending order, then by first name in descending order
df.sort_values(by=['last_name', 'first_name'], ascending=[True, False])
# Out:
#           last_name        first_name  height_cm  weight_kg  \
# 142        AL-ATHBA            Rashid        180        104
# 959       AL-HARTHI   Barakat Mubarak        171         67
# 1030  ALLEYNE-FORTE               Ade        180         73
# 1050         Abbadi             Ilyas        170         69
# 616          Abbate            Simona        171         64
# 140        Abdelaal            Hesham        167         52
# 738     Abdulrahman              Amer        168         68
# 218           Abian             Pablo        177         78
# 470        Abrantes           Arnaldo        184         78
# 1047          Abril             Erika        158         47
# 1027        Abshero             Ayele        168         62
# 278       Abu Drais           Methkal        168         62
# 1343         Achara            Kieron        208        110
# 927          Achour      Dallal Merwa        176         45
# 388            Adam           Idrissa        178         79
# 1315          Adams            Nicola        164         51
# 542           Adams           Lyukman        194         87
# 36            Adams           Antoine        180         79
# 1287         Adcock             Chris        183         80
# 1469         Adeoye          Margaret        162         65
# 1357      Adlington           Rebecca        179         70
# 153      Afroudakis          Georgios        194        103
# 623      Agamennoni              Luca        188         96
# 756       Agrafioti              Anna        178         76
# 320         Ahamada              Feta        160         50
# 1016          Ahmed  Abdou Omar Abdou        172         66
# 1048           Ahye      Michelle-Lee        160         64
# 266       Aidietyte           Neringa        177         61
# 1218        Ainslie               Ben        183         90
# 595          Akrout           Youssef        180         78
# ...             ...               ...        ...        ...
# 1544         Yankey            Rachel        164         56
# 156            Yano             Kyoko        165         60
# 107      Yaroshchuk             Hanna        176         57
# 795          Yazawa            Kazuki        167         65
# 402        Yeremyan             Arman        185         80
# 360             Yim          Junghyun        182         66
# 667           Young            Alison        181         67
# 1077         Yousif             Rabah        184         71
# 886              Yu         Peng Kean        176         65
# 668       Yurkovich            Rachel        180         70
# 737      Yushchanka           Yulyana        174         63
# 15          Yushkov              Ivan        192        130
# 904    Zabelinskaya              Olga        175         61
# 253          Zaiser              Lisa        174         63
# 381         Zaitsev        Kostiantyn        193         91
# 769          Zeller           Philipp        184         81
# 272          Zetlin             Julie        168         54
# 32           Zevina            Daryna        182         64
# 869        Zhakypov           Birzhan        167         49
# 1583          Zhang            Zhaoxu        219        110
# 536           Zhang               Jun        186        120
# 222           Zhang            Guowei        200         77
# 94             Zhao            Yudiao        174         70
# 358    Zhexembinova           Aigerim        164         47
# 476            Zhou              Peng        183         88
# 960            Zhou           Chunxiu        162         48
# 1093       Zlokovic             Boris        197        100
# 742          Zolnir             Urska        173         63
# 768           Zoric           Milenko        179         73
# 699           Zugaj             Nenad        177         84
#
#                     country country_code gender                  sport  \
# 142                   Qatar          QAT    NaN               Shooting
# 959                    Oman          OMA    NaN              Athletics
# 1030    Trinidad and Tobago          TRI    NaN              Athletics
# 1050                Algeria          ALG    NaN                 Boxing
# 616                   Italy          ITA      F             Water Polo
# 140                   Egypt          EGY    NaN                 Boxing
# 738    United Arab Emirates          UAE    NaN               Football
# 218                   Spain          ESP    NaN              Badminton
# 470                Portugal          POR    NaN              Athletics
# 1047               Colombia          COL      F              Athletics
# 1027               Ethiopia          ETH    NaN              Athletics
# 278                  Jordan          JOR    NaN              Athletics
# 1343                Team GB          GBR    NaN             Basketball
# 927                 Algeria          ALG      F             Volleyball
# 388                Cameroon          CMR    NaN              Athletics
# 1315                Team GB          GBR      F                 Boxing
# 542      Russian Federation          RUS    NaN              Athletics
# 36    Saint Kitts and Nevis          SKN    NaN              Athletics
# 1287                Team GB          GBR    NaN              Badminton
# 1469                Team GB          GBR      F              Athletics
# 1357                Team GB          GBR      F               Swimming
# 153                  Greece          GRE    NaN             Water Polo
# 623                   Italy          ITA    NaN                 Rowing
# 756                  Greece          GRE      F                Sailing
# 320                 Comoros          COM      F              Athletics
# 1016                  Egypt          EGY    NaN              Wrestling
# 1048    Trinidad and Tobago          TRI      F              Athletics
# 266               Lithuania          LTU      F              Athletics
# 1218                Team GB          GBR    NaN                Sailing
# 595                 Tunisia          TUN    NaN                Sailing
# ...                     ...          ...    ...                    ...
# 1544                Team GB          GBR      F               Football
# 156                   Japan          JPN      F               Football
# 107                 Ukraine          UKR      F              Athletics
# 795                   Japan          JPN    NaN           Canoe Slalom
# 402                 Armenia          ARM    NaN              Taekwondo
# 360             South Korea          KOR    NaN              Athletics
# 667                 Team GB          GBR      F                Sailing
# 1077                  Sudan          SUD    NaN              Athletics
# 886                Malaysia          MAS    NaN                Fencing
# 668                Team USA          NaN      F              Athletics
# 737                 Belarus          BLR      F              Athletics
# 15       Russian Federation          RUS    NaN              Athletics
# 904      Russian Federation          RUS      F         Cycling - Road
# 253                 Austria          AUT      F               Swimming
# 381                 Ukraine          UKR    NaN                 Rowing
# 769                 Germany          GER    NaN                 Hockey
# 272                Team USA          NaN      F  Gymnastics - Rhythmic
# 32                  Ukraine          UKR      F               Swimming
# 869              Kazakhstan          KAZ    NaN                 Boxing
# 1583                  China          CHN    NaN             Basketball
# 536                   China          CHN    NaN              Athletics
# 222                   China          CHN    NaN              Athletics
# 94                    China          CHN      F                 Hockey
# 358              Kazakhstan          KAZ      F  Synchronised Swimming
# 476                   China          CHN    NaN           Canoe Sprint
# 960                   China          CHN      F              Athletics
# 1093             Montenegro          MNE    NaN             Water Polo
# 742                Slovenia          SLO      F                   Judo
# 768                  Serbia          SRB    NaN           Canoe Sprint
# 699                 Croatia          CRO    NaN              Wrestling
#
#                                  event
# 142                         Men's Trap
# 959                         Men's 100m
# 1030              Men's 4 x 400m Relay
# 1050         Men's Welterweight (69kg)
# 616                 Women's Water Polo
# 140             Men's Flyweight (52kg)
# 738                     Men's Football
# 218                      Men's Singles
# 470                         Men's 200m
# 1047                  Women's Marathon
# 1027                    Men's Marathon
# 278                     Men's Marathon
# 1343                  Men's Basketball
# 927                 Women's Volleyball
# 388                         Men's 100m
# 1315          Women's Flyweight (51kg)
# 542                  Men's Triple Jump
# 36                          Men's 200m
# 1287                     Mixed Doubles
# 1469                      Women's 200m
# 1357            Women's 800m Freestyle
# 153                   Men's Water Polo
# 623                         Men's Four
# 756               Women's Laser Radial
# 320                       Women's 100m
# 1016              Men's Freestyle 66kg
# 1048                      Women's 100m
# 266                  Women's 20km Walk
# 1218                        Men's Finn
# 595                        Men's Laser
# ...                                ...
# 1544                  Women's Football
# 156                   Women's Football
# 107               Women's 400m Hurdles
# 795            Men's Kayak Single (K1)
# 402                        Men's -80kg
# 360                    Men's 50km Walk
# 667               Women's Laser Radial
# 1077                        Men's 400m
# 886             Men's Individual Sabre
# 668              Women's Javelin Throw
# 737             Women's 4 x 400m Relay
# 15                      Men's Shot Put
# 904      Women's Individual Time Trial
# 253     Women's 200m Individual Medley
# 381             Men's Quadruple Sculls
# 769                       Men's Hockey
# 272      Women's Individual All-Around
# 32    Women's 4 x 200m Freestyle Relay
# 869       Men's Light Flyweight (49kg)
# 1583                  Men's Basketball
# 536                     Men's Shot Put
# 222                    Men's High Jump
# 94                      Women's Hockey
# 358                      Women's Duets
# 476        Men's Kayak Four (K4) 1000m
# 960                   Women's Marathon
# 1093                  Men's Water Polo
# 742                      Women's -63kg
# 768        Men's Kayak Four (K4) 1000m
# 699             Men's Greco-Roman 84kg
#
# [1587 rows x 9 columns]

# %%
# Use a combination of: 
# .value_counts() 
# .head()
# to obtain the top 5 most common first names

df['first_name'].value_counts().head()
# Out:
# James      15
# Daniel     14
# Richard    12
# Peter      12
# Andrew     12
# Name: first_name, dtype: int64

# %%
# Sort by 'weight_kg' to obtain weights of the top 12 heaviest athletes.

df.sort_values(by='weight_kg', ascending=False).head(12)
# Out:
#         last_name   first_name  height_cm  weight_kg             country  \
# 1584      Blas Jr      Ricardo        185        218                Guam
# 553       Udachyn        Artem        186        160             Ukraine
# 1453   Myerscough         Carl        208        160             Team GB
# 201           Ota      Kazuomi        183        145               Japan
# 559      Majewski       Tomasz        204        142              Poland
# 708         Padar       Martin        194        140             Estonia
# 1172  Sherrington  Christopher        194        135             Team GB
# 15        Yushkov         Ivan        192        130  Russian Federation
# 161        Nikfar         Amin        198        130                Iran
# 1039        Okoye     Lawrence        197        129             Team GB
# 1159       Buhari        Abdul        192        125             Team GB
# 1060      Hoshina     Tomohiko        180        125         Philippines
#
#      country_code gender          sport               event
# 1584          GUM    NaN           Judo        Men's +100kg
# 553           UKR    NaN  Weightlifting        Men's +105kg
# 1453          GBR    NaN      Athletics  Men's Discus Throw
# 201           JPN    NaN  Weightlifting        Men's +105kg
# 559           POL    NaN      Athletics      Men's Shot Put
# 708           EST    NaN           Judo        Men's +100kg
# 1172          GBR    NaN           Judo        Men's +100kg
# 15            RUS    NaN      Athletics      Men's Shot Put
# 161           IRI    NaN      Athletics      Men's Shot Put
# 1039          GBR    NaN      Athletics  Men's Discus Throw
# 1159          GBR    NaN      Athletics  Men's Discus Throw
# 1060          PHI    NaN           Judo        Men's +100kg

# %%
# Sort the above alphabetically by Last Name, then First Name

heaviest = df.sort_values(by='weight_kg', ascending=False).head(12)
heaviest.sort_values(by=['last_name', 'first_name'])
# Out:
#         last_name   first_name  height_cm  weight_kg             country  \
# 1584      Blas Jr      Ricardo        185        218                Guam
# 1159       Buhari        Abdul        192        125             Team GB
# 1060      Hoshina     Tomohiko        180        125         Philippines
# 559      Majewski       Tomasz        204        142              Poland
# 1453   Myerscough         Carl        208        160             Team GB
# 161        Nikfar         Amin        198        130                Iran
# 1039        Okoye     Lawrence        197        129             Team GB
# 201           Ota      Kazuomi        183        145               Japan
# 708         Padar       Martin        194        140             Estonia
# 1172  Sherrington  Christopher        194        135             Team GB
# 553       Udachyn        Artem        186        160             Ukraine
# 15        Yushkov         Ivan        192        130  Russian Federation
#
#      country_code gender          sport               event
# 1584          GUM    NaN           Judo        Men's +100kg
# 1159          GBR    NaN      Athletics  Men's Discus Throw
# 1060          PHI    NaN           Judo        Men's +100kg
# 559           POL    NaN      Athletics      Men's Shot Put
# 1453          GBR    NaN      Athletics  Men's Discus Throw
# 161           IRI    NaN      Athletics      Men's Shot Put
# 1039          GBR    NaN      Athletics  Men's Discus Throw
# 201           JPN    NaN  Weightlifting        Men's +105kg
# 708           EST    NaN           Judo        Men's +100kg
# 1172          GBR    NaN           Judo        Men's +100kg
# 553           UKR    NaN  Weightlifting        Men's +105kg
# 15            RUS    NaN      Athletics      Men's Shot Put

# %% [markdown]
# # <span style="color: #20B2AA">Step 4: How to Filter</span>
#
# ### There are two ways to filter on a column name
#
# ```python
# df.column_name
# ```
# (only works if there are no spaces or special characters in the name)
#
# ```python
# df['COLUMN']
# ```
#
# ```python
# df[ ['COLUMN 1', 'COLUMN 2'] ]
# ```
#
# Accessing a single column returns a Series, and multiple columns return a DataFrame.
# I personally prefer to use the first method and find it faster.

# %%
# Filter for the height column. This returns a Series

df.height_cm
# Out:
# 0       204
# 1       190
# 2       184
# 3       183
# 4       188
# 5       167
# 6       202
# 7       190
# 8       193
# 9       178
# 10      183
# 11      160
# 12      164
# 13      183
# 14      170
# 15      192
# 16      178
# 17      171
# 18      168
# 19      163
# 20      179
# 21      205
# 22      170
# 23      178
# 24      173
# 25      170
# 26      182
# 27      173
# 28      162
# 29      198
#        ...
# 1557    172
# 1558    187
# 1559    188
# 1560    192
# 1561    185
# 1562    170
# 1563    162
# 1564    188
# 1565    170
# 1566    178
# 1567    186
# 1568    155
# 1569    194
# 1570    178
# 1571    193
# 1572    185
# 1573    183
# 1574    178
# 1575    181
# 1576    167
# 1577    157
# 1578    178
# 1579    193
# 1580    196
# 1581    171
# 1582    163
# 1583    219
# 1584    185
# 1585    136
# 1586    175
# Name: height_cm, dtype: float64

# %%
type(df.height_cm.tail(8))
# Out:
# pandas.core.series.Series

# %%
# Display the first name, last name and country columns.
# df[['first_name', 'last_name', 'country']]
# Display the country column first
# df[['country', 'first_name', 'last_name']]
# Sort it by First Name, in descending order
df[['country', 'first_name', 'last_name']].sort_values(by='first_name', ascending=False)
# This returns a DataFrame
# Out:
#                       country                 first_name        last_name
# 607                    Sweden            von GEIJER Jona       Von Geijer
# 1353                  Team GB            van der WEEL Zo     Van Der Weel
# 910               Netherlands        van der HORST Rober    Van Der Horst
# 912                   Belgium  van REGEMORTEL Anne-Sophi   Van Regemortel
# 256                    Canada          van KOEVERDEN Ada    Van Koeverden
# 736                   Belgium           van HOVE Benjami         Van Hove
# 1021              Netherlands              van HOUTS Rud        Van Houts
# 412                     Egypt                      eldin             Saad
# 328                   Belgium            de VOS Charlott           De Vos
# 290                     Italy            de VECCHI Manue        De Vecchi
# 419                     Italy             de NICOLO Marc        De Nicolo
# 47                     France               de COLO Nand          De Colo
# 697                    Brazil              da SILVA Fabi         Da Silva
# 433            Czech Republic                     Zuzana          Hejnova
# 228                     China                        Zuo             Chen
# 579                    Poland                      Zofia  NOCETI-KLEPACKA
# 1444                  Team GB                        Zoe            Smith
# 53                  Lithuania                    Zinaida        Sendriute
# 141                     China                       Zige              Liu
# 387                 Singapore                         Zi             Yang
# 38                      Spain                     Zhiwen               He
# 1583                    China                     Zhaoxu            Zhang
# 958                    Poland                   Zbigniew       Schodowski
# 1258                  Team GB                       Zara          Dampney
# 1309                  Team GB                       Zara         Phillips
# 295                     Niger                     Zakari         Gourouza
# 1320                  Team GB                        Zac         Purchase
# 1203                  Team GB                     Yvonne         Leuthold
# 878                   Team GB                     Yvette            Baker
# 870                     China                     Yutong              Luo
# ...                       ...                        ...              ...
# 120                  Cameroon                      Ajara           Nchout
# 876                     Japan                       Airi       Hatakeyama
# 1557                  Team GB                      Aimee         Willmott
# 358                Kazakhstan                    Aigerim     Zhexembinova
# 860        Russian Federation                       Aida         Shanaeva
# 326                   Hungary                       Aida          Mohamed
# 243                     Egypt                      Ahmed           Bekhit
# 813                     Egypt                      Ahmed            Fathi
# 196                    Poland                  Agnieszka           Jerzyk
# 488                    Poland                  Agnieszka       Skrzypulec
# 516                     Italy                     Agnese        Allegrini
# 1195               Cape Verde                 Adysangela            Moniz
# 678                    Brazil                    Adriana            Pinto
# 787                    Brazil                    Adriana           Araujo
# 627                    Greece                     Adonia         Steryiou
# 1030      Trinidad and Tobago                        Ade    ALLEYNE-FORTE
# 126              Burkina Faso                      Adama        Ouedraogo
# 1443                  Team GB                       Adam          Johnson
# 1251                  Team GB                       Adam      Scholefield
# 1436                  Team GB                       Adam            Brown
# 350   Australian Olympic Team                       Adam           Rutter
# 1361                  Team GB                    Abiodun         Oyepitan
# 1480                  Team GB                    Abigail          Edmonds
# 55                    Uruguay                       Abel        Hernandez
# 224        Russian Federation                  Abdusalam          Gadisov
# 1159                  Team GB                      Abdul           Buhari
# 1016                    Egypt           Abdou Omar Abdou            Ahmed
# 317                     Egypt                Abdelrahman        Eltrabily
# 1464                  Team GB                      Aaron           Ramsey
# 282                    Brazil                        NaN           Baiana
#
# [1587 rows x 3 columns]

# %% [markdown]
# ### Filtering based on a Condition:
#
# <img src = http://i.imgur.com/iETVE07.png width=640>

# %%
# Filter for all Canadian athletes
condition = df.country == 'Canada'
df[condition]
# Out:
#          last_name         first_name  height_cm  weight_kg country  \
# 11       Cheverton           Samantha        160         48  Canada
# 25          Duenas            Crispin        170         81  Canada
# 60           Booth            Melanie        175         65  Canada
# 91         Spencer               Mary        180         73  Canada
# 136      Wilkinson            Michael        188         86  Canada
# 173         Howard            Malcolm        200        100  Canada
# 183         Millar                Ian        185         76  Canada
# 220          Leigh               Mike        179         73  Canada
# 225          Pliev             Khetag        182         96  Canada
# 233         Mccabe       McCABE Conli        205        100  Canada
# 250         Cotton                Amy        180         78  Canada
# 256  Van Koeverden  van KOEVERDEN Ada        182         85  Canada
# 331          Isaac              Chloe        169         57  Canada
# 384        Michaud          Sebastien        185         78  Canada
# 420       Sinclair          Christine        175         67  Canada
# 441          Gayle              Robyn        168         65  Canada
# 485        Heymans             Emilie        170         62  Canada
# 515        Leclair          Stephanie        172         54  Canada
# 610        Russell              Colin        192         90  Canada
# 670         Foster            Tiffany        165         50  Canada
# 679       Melancon            Joliane        170         57  Canada
# 692        Stewart            Chelsea        165         54  Canada
# 695    Braithwaite            Michael        189         91  Canada
# 723          Tyler            Jillian        152         65  Canada
# 731        Lacroix             Audrey        163         53  Canada
# 735      Jennerich            Lindsay        165         59  Canada
# 829      Mccormick     McCORMICK Rile        172         66  Canada
# 885        Gleadle          Elizabeth        185         84  Canada
# 963         Nyhaug               Tory        185         90  Canada
#
#     country_code gender                  sport  \
# 11           CAN      F               Swimming
# 25           CAN    NaN                Archery
# 60           CAN      F               Football
# 91           CAN      F                 Boxing
# 136          CAN    NaN                 Rowing
# 173          CAN    NaN                 Rowing
# 183          CAN    NaN             Equestrian
# 220          CAN    NaN                Sailing
# 225          CAN    NaN              Wrestling
# 233          CAN    NaN                 Rowing
# 250          CAN      F                   Judo
# 256          CAN    NaN           Canoe Sprint
# 331          CAN      F  Synchronised Swimming
# 384          CAN    NaN              Taekwondo
# 420          CAN      F               Football
# 441          CAN      F               Football
# 485          CAN      F                 Diving
# 515          CAN      F  Synchronised Swimming
# 610          CAN    NaN               Swimming
# 670          CAN      F             Equestrian
# 679          CAN      F                   Judo
# 692          CAN      F               Football
# 695          CAN    NaN                 Rowing
# 723          CAN      F               Swimming
# 731          CAN      F               Swimming
# 735          CAN      F                 Rowing
# 829          CAN    NaN                 Diving
# 885          CAN      F              Athletics
# 963          CAN    NaN          Cycling - BMX
#
#                                    event
# 11                Women's 200m Freestyle
# 25                      Men's Individual
# 60                      Women's Football
# 91           Women's Middleweight (75kg)
# 136                           Men's Four
# 173                          Men's Eight
# 183                   Individual Jumping
# 220                            Men's 470
# 225                 Men's Freestyle 96kg
# 233                          Men's Eight
# 250                        Women's -78kg
# 256        Men's Kayak Single (K1) 1000m
# 331                        Women's Teams
# 384                          Men's -80kg
# 420                     Women's Football
# 441                     Women's Football
# 485  Women's Synchronised 3m Springboard
# 515                        Women's Teams
# 610       Men's 4 x 200m Freestyle Relay
# 670                   Individual Jumping
# 679                        Women's -57kg
# 692                     Women's Football
# 695                  Men's Double Sculls
# 723            Women's 100m Breaststroke
# 731               Women's 200m Butterfly
# 735    Women's Lightweight Double Sculls
# 829                   Men's 10m Platform
# 885                Women's Javelin Throw
# 963                            Men's BMX

# %% [markdown]
# ### Filtering on multiple conditions

# %%
# Filter for all the Canadians that are taller than 190cm:
conditions = (df.country == 'Canada') & (df.height_cm > 190)
df[conditions]
# Out:
#     last_name    first_name  height_cm  weight_kg country country_code gender  \
# 173    Howard       Malcolm        200        100  Canada          CAN    NaN
# 233    Mccabe  McCABE Conli        205        100  Canada          CAN    NaN
# 610   Russell         Colin        192         90  Canada          CAN    NaN
#
#         sport                           event
# 173    Rowing                     Men's Eight
# 233    Rowing                     Men's Eight
# 610  Swimming  Men's 4 x 200m Freestyle Relay

# %%
# Filter for
# all the Canadians that are taller than 190cm 
# OR for any athlete from Rwanda. 
# Then, sort by country in alphabetical order

condition_canada = df.country == 'Canada'
condition_height = df.height_cm > 190  
condition_rwanda = df.country == 'Rwanda'
conditions = (condition_canada & condition_height) | (condition_rwanda)

df[conditions]
# Out:
#       last_name    first_name  height_cm  weight_kg country country_code  \
# 2    Niyomugabo       Jackson        184         71  Rwanda          RWA
# 173      Howard       Malcolm        200        100  Canada          CAN
# 233      Mccabe  McCABE Conli        205        100  Canada          CAN
# 610     Russell         Colin        192         90  Canada          CAN
#
#     gender     sport                           event
# 2      NaN  Swimming             Men's 50m Freestyle
# 173    NaN    Rowing                     Men's Eight
# 233    NaN    Rowing                     Men's Eight
# 610    NaN  Swimming  Men's 4 x 200m Freestyle Relay

# %%
# Filter for all where First Name is Colin, return only the height, sorted from smallest to largest
df[df.first_name == 'Colin']['height_cm'].sort_values()
# Out:
# 1529    181
# 1483    188
# 610     192
# Name: height_cm, dtype: float64

# %%
# Filter for all where First Name is Colin and store their heights in a variable called heights. 
# Then display the mean of their heights 
heights = df[df.first_name == 'Colin']['height_cm']
heights.mean()
# Out:
# 187.0

# %% [markdown]
# ### Slicing the dataframe
#
# ### For now, we will use .ix[rows, columns] to slice by column name or position
# * Some notation:
# > for rows/columns 0 to 5 inclusive use ```1:10```
# >
# > for all rows/columns use ```:```

# %%
# All rows and all columns

df.ix[:,:]
# Out:
#           last_name        first_name  height_cm  weight_kg  \
# 0             Pipes               Ben        204         90
# 1         Bolshakov            Sergey        190         90
# 2        Niyomugabo           Jackson        184         71
# 3         Palameika            Madara        183         76
# 4           Sibello        Gianfranco        188         84
# 5           Kulkina              Anna        167         52
# 6         Degtyarev              Egor        202         96
# 7            Garcia  Fernando Gabriel        190         85
# 8            Kynard              Erik        193         86
# 9         Taouerghi            Anouer        178         77
# 10         O'KEEFFE           Michael        183         78
# 11        Cheverton          Samantha        160         48
# 12           Takano               Aya        164         54
# 13            Sakai            Hiroki        183         70
# 14          Eastham             Casey        170         62
# 15          Yushkov              Ivan        192        130
# 16           Kalmer              Rene        178         49
# 17        Hladikova             Aneta        171         62
# 18       Bernardova              Sona        168         55
# 19    Tenorio Silva              Rosa        163         69
# 20         Campazzo           Facundo        179         88
# 21          Ghayaza           Mokhtar        205        106
# 22            Lucas            Dakota        170         68
# 23           Mullin            Shauna        178         74
# 24          Wiersum             Peter        173         55
# 25           Duenas           Crispin        170         81
# 26         Yamamoto             Kohei        182         69
# 27     Kvyatkovskyy            Andriy        173         71
# 28           Tejeda            Gladys        162         46
# 29        Aranowski          Krystian        198        100
# ...             ...               ...        ...        ...
# 1557       Willmott             Aimee        172         56
# 1558         Waller              Jack        187         95
# 1559       Robinson              Glen        188         90
# 1560      Honeybone             James        192         81
# 1561           Foad             James        185         90
# 1562          Reade           Shanaze        170         76
# 1563       Gladding           Monique        162         57
# 1564         Austin             James        188        100
# 1565          White             Ellen        170         58
# 1566         Vernon             Annie        178         75
# 1567       Loughran             Marco        186         75
# 1568         Knobbs          Jennifer        155         49
# 1569        Johnson              Kyle        194         93
# 1570           Webb             David        178         62
# 1571       Mccarthy      McCARTHY Ale        193         88
# 1572       Williams               Rob        185         75
# 1573       Chambers           Richard        183         74
# 1574        Godfrey             Larry        178         84
# 1575       Marshall          Savannah        181         75
# 1576          Okoro           Marilyn        167         60
# 1577         Pooley              Emma        157         48
# 1578           Ling                Ed        178         76
# 1579         Pinner            George        193         93
# 1580         Bakare             Peter        196         93
# 1581      Dobriskey              Lisa        171         56
# 1582        Goodwin             Britt        163         68
# 1583          Zhang            Zhaoxu        219        110
# 1584        Blas Jr           Ricardo        185        218
# 1585       Teramoto             Asuka        136         30
# 1586            Ali              Asad        175         82
#
#                       country country_code gender                    sport  \
# 0                     Team GB          GBR    NaN               Volleyball
# 1          Russian Federation          RUS    NaN                 Swimming
# 2                      Rwanda          RWA    NaN                 Swimming
# 3                      Latvia          LAT      F                Athletics
# 4                       Italy          ITA    NaN                  Sailing
# 5                  Kazakhstan          KAZ      F    Synchronised Swimming
# 6          Russian Federation          RUS    NaN                 Swimming
# 7                   Argentina          ARG    NaN                 Handball
# 8                    Team USA          NaN    NaN                Athletics
# 9                     Tunisia          TUN    NaN               Volleyball
# 10                New Zealand          NZL    NaN                 Football
# 11                     Canada          CAN      F                 Swimming
# 12                      Japan          JPN      F                 Swimming
# 13                      Japan          JPN    NaN                 Football
# 14    Australian Olympic Team          AUS      F                   Hockey
# 15         Russian Federation          RUS    NaN                Athletics
# 16               South Africa          RSA      F                Athletics
# 17             Czech Republic          CZE      F            Cycling - BMX
# 18             Czech Republic          CZE      F    Synchronised Swimming
# 19                    Ecuador          ECU      F            Weightlifting
# 20                  Argentina          ARG    NaN               Basketball
# 21                    Tunisia          TUN    NaN               Basketball
# 22                New Zealand          NZL    NaN                 Football
# 23                    Team GB          GBR      F         Beach Volleyball
# 24                Netherlands          NED    NaN                   Rowing
# 25                     Canada          CAN    NaN                  Archery
# 26                      Japan          JPN    NaN  Cycling - Mountain Bike
# 27                    Ukraine          UKR    NaN                Wrestling
# 28                       Peru          PER      F                Athletics
# 29                     Poland          POL    NaN                   Rowing
# ...                       ...          ...    ...                      ...
# 1557                  Team GB          GBR      F                 Swimming
# 1558                  Team GB          GBR    NaN               Water Polo
# 1559                  Team GB          GBR    NaN               Water Polo
# 1560                  Team GB          GBR    NaN                  Fencing
# 1561                  Team GB          GBR    NaN                   Rowing
# 1562                  Team GB          GBR      F            Cycling - BMX
# 1563                  Team GB          GBR      F                   Diving
# 1564                  Team GB          GBR    NaN                     Judo
# 1565                  Team GB          GBR      F                 Football
# 1566                  Team GB          GBR      F                   Rowing
# 1567                  Team GB          GBR    NaN                 Swimming
# 1568                  Team GB          GBR      F    Synchronised Swimming
# 1569                  Team GB          GBR    NaN               Basketball
# 1570                  Team GB          GBR    NaN                Athletics
# 1571                  Team GB          GBR    NaN                 Football
# 1572                  Team GB          GBR    NaN                   Rowing
# 1573                  Team GB          GBR    NaN                   Rowing
# 1574                  Team GB          GBR    NaN                  Archery
# 1575                  Team GB          GBR      F                   Boxing
# 1576                  Team GB          GBR      F                Athletics
# 1577                  Team GB          GBR      F           Cycling - Road
# 1578                  Team GB          GBR    NaN                 Shooting
# 1579                  Team GB          GBR    NaN                   Hockey
# 1580                  Team GB          GBR    NaN               Volleyball
# 1581                  Team GB          GBR      F                Athletics
# 1582                  Team GB          GBR      F                 Handball
# 1583                    China          CHN    NaN               Basketball
# 1584                     Guam          GUM    NaN                     Judo
# 1585                    Japan          JPN      F    Gymnastics - Artistic
# 1586                   Zambia          ZMB      M                  Archery
#
#                                  event
# 0                     Men's Volleyball
# 1                  Men's Marathon 10km
# 2                  Men's 50m Freestyle
# 3                Women's Javelin Throw
# 4                           Men's 49er
# 5                        Women's Duets
# 6                 Men's 400m Freestyle
# 7                       Men's Handball
# 8                      Men's High Jump
# 9                     Men's Volleyball
# 10                      Men's Football
# 11              Women's 200m Freestyle
# 12    Women's 4 x 200m Freestyle Relay
# 13                      Men's Football
# 14                      Women's Hockey
# 15                      Men's Shot Put
# 16                    Women's Marathon
# 17                         Women's BMX
# 18                       Women's Duets
# 19                        Women's 69kg
# 20                    Men's Basketball
# 21                    Men's Basketball
# 22                      Men's Football
# 23            Women's Beach Volleyball
# 24                         Men's Eight
# 25                    Men's Individual
# 26                 Men's Mountain Bike
# 27                Men's Freestyle 66kg
# 28                    Women's Marathon
# 29                         Men's Eight
# ...                                ...
# 1557    Women's 400m Individual Medley
# 1558                  Men's Water Polo
# 1559                  Men's Water Polo
# 1560            Men's Individual Sabre
# 1561                       Men's Eight
# 1562                       Women's BMX
# 1563              Women's 10m Platform
# 1564                      Men's -100kg
# 1565                  Women's Football
# 1566                     Women's Eight
# 1567             Men's 200m Backstroke
# 1568                     Women's Teams
# 1569                  Men's Basketball
# 1570                    Men's Marathon
# 1571                    Men's Football
# 1572            Men's Lightweight Four
# 1573            Men's Lightweight Four
# 1574                  Men's Individual
# 1575       Women's Middleweight (75kg)
# 1576            Women's 4 x 400m Relay
# 1577     Women's Individual Time Trial
# 1578                        Men's Trap
# 1579                      Men's Hockey
# 1580                  Men's Volleyball
# 1581                     Women's 1500m
# 1582                  Women's Handball
# 1583                  Men's Basketball
# 1584                      Men's +100kg
# 1585            Women's Qualifications
# 1586                  Men's Individual
#
# [1587 rows x 9 columns]

# %%
# By position

df.ix[1:10, [1,4,5]]
# Out:
#           first_name             country country_code
# 1             Sergey  Russian Federation          RUS
# 2            Jackson              Rwanda          RWA
# 3             Madara              Latvia          LAT
# 4         Gianfranco               Italy          ITA
# 5               Anna          Kazakhstan          KAZ
# 6               Egor  Russian Federation          RUS
# 7   Fernando Gabriel           Argentina          ARG
# 8               Erik            Team USA          NaN
# 9             Anouer             Tunisia          TUN
# 10           Michael         New Zealand          NZL

# %%
# By position and label

df.ix[10:15, 'first_name':'sport']
# Out:
#    first_name  height_cm  weight_kg                  country country_code  \
# 10    Michael        183         78              New Zealand          NZL
# 11   Samantha        160         48                   Canada          CAN
# 12        Aya        164         54                    Japan          JPN
# 13     Hiroki        183         70                    Japan          JPN
# 14      Casey        170         62  Australian Olympic Team          AUS
# 15       Ivan        192        130       Russian Federation          RUS
#
#    gender      sport
# 10    NaN   Football
# 11      F   Swimming
# 12      F   Swimming
# 13    NaN   Football
# 14      F     Hockey
# 15    NaN  Athletics

# %% [markdown]
# #### Exercises:

# %% [markdown]
# #### Filter for all female athletes, and display last 5 rows

# %%
df[df.gender == 'F'].tail()
# Out:
#       last_name first_name  height_cm  weight_kg  country country_code gender  \
# 1576      Okoro    Marilyn        167         60  Team GB          GBR      F
# 1577     Pooley       Emma        157         48  Team GB          GBR      F
# 1581  Dobriskey       Lisa        171         56  Team GB          GBR      F
# 1582    Goodwin      Britt        163         68  Team GB          GBR      F
# 1585   Teramoto      Asuka        136         30    Japan          JPN      F
#
#                       sport                          event
# 1576              Athletics         Women's 4 x 400m Relay
# 1577         Cycling - Road  Women's Individual Time Trial
# 1581              Athletics                  Women's 1500m
# 1582               Handball               Women's Handball
# 1585  Gymnastics - Artistic         Women's Qualifications

# %% [markdown]
# #### Filter for all athletes whose sport is Swimming and sort them from tallest to shortest, then display first five

# %%
df[df.sport == 'Swimming'].sort_values(by='height_cm', ascending=False).head()
# Out:
#       last_name first_name  height_cm  weight_kg             country  \
# 6     Degtyarev       Egor        202         96  Russian Federation
# 400     Timmers     Pieter        200         89             Belgium
# 874          Li     Xiayan        199         98               China
# 1032    Grechin     Andrey        198         94  Russian Federation
# 379       Moore     Graeme        198         98        South Africa
#
#      country_code gender     sport                           event
# 6             RUS    NaN  Swimming            Men's 400m Freestyle
# 400           BEL    NaN  Swimming  Men's 4 x 200m Freestyle Relay
# 874           CHN    NaN  Swimming         Men's 100m Breaststroke
# 1032          RUS    NaN  Swimming  Men's 4 x 100m Freestyle Relay
# 379           RSA    NaN  Swimming  Men's 4 x 100m Freestyle Relay

# %% [markdown]
# #### Filter for all athletes that are from Great Britain and shorter than 1.60m, whose first name is Rebecca

# %%
gb = df.country == 'Team GB'
height = df.height_cm < 160
name_rebecca = df.first_name == 'Rebecca'

df[gb & height & name_rebecca]
# Out:
#      last_name first_name  height_cm  weight_kg  country country_code gender  \
# 345     Tunney    Rebecca        149         35  Team GB          GBR      F
# 1103    Turner    Rebecca        153         68  Team GB          GBR      F
#
#                       sport                   event
# 345   Gymnastics - Artistic  Women's Qualifications
# 1103               Swimming  Women's 200m Freestyle

# %% [markdown]
# #### Obtain the first 5 names of all athletes that participate in Rowing with event Women's Eight
# ### OR
# #### any kind of Swimming, then sort them by country from A->Z

# %%
rowing = df.sport == 'Rowing'
event = df.event == "Women's Eight"
swimming = df.sport == 'Swimming'

conditions = (rowing & event) | swimming

df[conditions].sort_values(by='country').head()
# Out:
#        last_name first_name  height_cm  weight_kg                  country  \
# 1094     Fonteno      Megan        163         61           American Samoa
# 917     Biagioli    Cecilia        165         52                Argentina
# 432      Tranter     Daniel        193         80  Australian Olympic Team
# 875   Chatterton      Renee        185         78  Australian Olympic Team
# 500        Evans      Blair        175         65  Australian Olympic Team
#
#      country_code gender     sport                           event
# 1094          ASA      F  Swimming          Women's 100m Freestyle
# 917           ARG      F  Swimming          Women's 800m Freestyle
# 432           AUS    NaN  Swimming    Men's 200m Individual Medley
# 875           AUS      F    Rowing                   Women's Eight
# 500           AUS      F  Swimming  Women's 400m Individual Medley

# %% [markdown]
# # <span style="color: #20B2AA">Step 5: Cleaning Up the Data Set </span>
#
#
# ### We've already found three things in our data set:
# 1. Someone is missing a first name!
# 2. There are no males in the original dataset
# 3. Team USA is messing their country code

# %%
# Find the poor soul that's missing their first name

df[df.first_name.isnull()]
# Out:
#     last_name first_name  height_cm  weight_kg country country_code gender  \
# 282    Baiana        NaN        161         56  Brazil          BRA      F
#
#         sport             event
# 282  Football  Women's Football

# %%
# To fill, use .fillna()
# I found Fabiana on Wikipedia and used that as the source

df.first_name = df.first_name.fillna('Fabiana')

# %%
# Filter for all male athletes

df.gender.value_counts()

df.gender = df.gender.fillna('M')

# %%
# Confirm that only Team USA is missing a country code.
# To do this: 
# Filter for all country codes that are null
# Return the unique values in the country column
print 'The countries that are missing country code are: ' + df[df.country_code.isnull()]['country'].unique()

# Fill them in with 'USA'
df.country_code = df.country_code.fillna('USA')
# Out:
# ['The countries that are missing country code are: Team USA']

# %%
#check to see if Team USA has a country code now:
df[df.country == 'Team USA'].head(2)
# Out:
#    last_name first_name  height_cm  weight_kg   country country_code gender  \
# 8     Kynard       Erik        193         86  Team USA          USA      M
# 44   Lofgren     Esther        188         79  Team USA          USA      F
#
#         sport            event
# 8   Athletics  Men's High Jump
# 44     Rowing    Women's Eight

# %% [markdown]
# <h2 style="color: #FD2E33">
# Save the data set using [.to_csv()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html)</h2>
#
# >```python
# df.to_csv('clean_data.csv', index=False)
# ```

# %%
df.to_csv('clean_data.csv', index=False)

# %% [markdown]
# # <span style="color: #20B2AA">Step 6:  Analyse Data and Create Charts</span>
# ### We will answer these questions:
# * Create a histogram of all heights and weights
# * Create a horizontal bar chart of the median heights for Team GB Athletes, by sport
#
# ---
#
# ### We are going to do all of this using [.groupby()](http://pandas.pydata.org/pandas-docs/stable/groupby.html)
#
# > ### Split - Splitting the data into groups based on some criteria
# > ### Apply - Applying a function to each group independently
# >> - .sum()
# > - .count()
# > - .mean()
# > - .std()
# > - .size()
# > - .apply()
# >
# >### Combine - Combining the results into a data structure
#
# >### Use ```.get_group( ) ``` to access a group
#
# ---
# <img src="http://i.imgur.com/yjNkiwL.png">
#
# Source: Gratuitously borrowed from Hadley Wickham's Data Science in R slides

# %% [markdown]
# ### Plotting cheat sheet
# ```python
# Use .plot(kind=' ')
# ```
#
# Fill in the quotes with one of the plots below
# >- ‘bar’  ‘barh’ for bar plots
# >- ‘hist’ for histogram
# >- ‘box’ for boxplot
# >- ‘kde’ or 'density' for density plots
# >- ‘area’ for area plots
# >- ‘scatter’ for scatter plots
# >- ‘hexbin’ for hexagonal bin plots
# >- ‘pie’ for pie plots
#
# [The extensive documentation can be found here](http://pandas.pydata.org/pandas-docs/stable/visualization.html)

# %%
# Histogram of heights and weights
df.plot(kind='hist', bins=20)

# %%
# Example of groupby. 
# Split by country and sport
# Aggregate by the median
# Use .ix to isolate Team GB
# Display just the height_cm column
# Sort from tallest to shortest
# Obtain the top 5
# Present in a horizontal bar chart


#df.groupby(['country', 'sport']).median().ix['Team GB']['height_cm'].sort_values(ascending=False).tail(5).plot(kind='barh')

df.groupby(['country', 'sport']).median()
# Out:
#                                                  height_cm  weight_kg
# country                 sport
# Afghanistan             Taekwondo                    184.0       80.0
# Albania                 Weightlifting                186.0       94.0
# Algeria                 Boxing                       170.0       69.0
#                         Rowing                       173.0       59.0
#                         Volleyball                   170.5       45.0
# American Samoa          Swimming                     163.0       61.0
# American Virgin Islands Athletics                    173.0       68.0
# Andorra                 Athletics                    175.0       64.0
# Angola                  Canoe Sprint                 168.0       67.0
#                         Handball                     173.0       71.5
#                         Judo                         170.0       68.0
# Antigua and Barbuda     Athletics                    179.0       68.0
# Argentina               Athletics                    172.0       54.0
#                         Basketball                   179.0       88.0
#                         Boxing                       179.5       73.5
#                         Handball                     190.0       88.5
#                         Hockey                       157.0       54.0
#                         Judo                         150.0       48.0
#                         Shooting                     180.0       90.0
#                         Swimming                     165.0       52.0
#                         Tennis                       183.0       79.0
# Armenia                 Gymnastics - Artistic        162.0       64.0
#                         Taekwondo                    185.0       80.0
#                         Weightlifting                175.0       85.0
# Aruba                   Judo                         170.0       66.0
# Australian Olympic Team Athletics                    184.0       76.0
#                         Badminton                    181.0       72.0
#                         Basketball                   209.0       98.0
#                         Boxing                       180.0       80.0
#                         Canoe Slalom                 186.0       79.0
# ...                                                    ...        ...
# Ukraine                 Athletics                    178.0       67.0
#                         Cycling - Track              166.0       65.0
#                         Diving                       160.5       53.5
#                         Fencing                      167.0       58.0
#                         Gymnastics - Artistic        158.0       50.0
#                         Gymnastics - Rhythmic        172.0       48.0
#                         Gymnastics - Trampoline      162.0       52.0
#                         Rowing                       194.0       97.5
#                         Shooting                     170.0       75.0
#                         Swimming                     178.0       68.0
#                         Weightlifting                186.0      160.0
#                         Wrestling                    173.0       71.0
# United Arab Emirates    Football                     168.0       68.0
# Uruguay                 Football                     185.0       73.0
#                         Rowing                       177.0       70.0
# Uzbekistan              Judo                         180.0      100.0
#                         Swimming                     174.0       61.0
#                         Weightlifting                183.0      105.0
# Vanuatu                 Athletics                    166.0       55.0
# Venezuela               Athletics                    170.0       65.0
#                         Beach Volleyball             189.0       87.0
#                         Boxing                       173.0       75.0
#                         Cycling - Road               168.0       60.0
#                         Diving                       151.0       47.0
#                         Wrestling                    165.0       57.5
# Vietnam                 Swimming                     165.0       58.0
#                         Weightlifting                155.0       53.0
# Yemen                   Athletics                    168.0       49.0
# Zambia                  Archery                      175.0       82.0
# Zimbabwe                Athletics                    162.0       64.0
#
# [688 rows x 2 columns]

# %%
df.groupby(['country', 'sport']).median().ix['Team GB']
# Out:
#                          height_cm  weight_kg
# sport
# Archery                      176.5       79.5
# Athletics                    178.0       69.0
# Badminton                    175.5       72.5
# Basketball                   190.0       86.5
# Beach Volleyball             185.0       83.0
# Boxing                       178.0       62.0
# Canoe Slalom                 182.0       77.0
# Canoe Sprint                 176.5       75.5
# Cycling - BMX                174.0       79.5
# Cycling - Mountain Bike      170.0       62.5
# Cycling - Road               175.0       69.0
# Cycling - Track              177.0       70.0
# Diving                       166.0       60.5
# Equestrian                   175.0       68.0
# Fencing                      177.0       67.0
# Football                     175.0       65.0
# Gymnastics - Artistic        163.5       58.0
# Gymnastics - Rhythmic        170.0       58.0
# Gymnastics - Trampoline      168.0       56.0
# Handball                     182.0       76.0
# Hockey                       176.0       74.0
# Judo                         175.0       70.0
# Modern Pentathlon            180.5       74.5
# Rowing                       187.0       78.0
# Sailing                      179.0       71.0
# Shooting                     175.0       75.0
# Swimming                     179.5       75.0
# Synchronised Swimming        170.0       54.0
# Table Tennis                 178.0       65.5
# Taekwondo                    179.0       67.5
# Tennis                       184.0       74.0
# Triathlon                    178.0       64.0
# Volleyball                   186.0       81.0
# Water Polo                   181.0       80.0
# Weightlifting                168.0       70.0
# Wrestling                    160.0       60.0

# %%
heights = df.groupby(['country', 'sport']).median().ix['Team GB']['height_cm']
top_5_tallest = heights.sort_values(ascending=False).head(5)
top_5_tallest.plot(kind='barh')

# %% [markdown]
# # <span style="color: #20B2AA">Step 7:  Creating Our Visualisation</span>

# %%
df.plot(kind='scatter',
        x='weight_kg',
        y='height_cm',
        title='Your Olympic Athlete Body Match',
        marker='s',
        color='orange',
        figsize=(10,8))

# %% [markdown]
# # <span style="color: #20B2AA">Cheat Sheet</span>
#
# **Basic Operations**
#
# ```python
# len(df)       # returns the lenght of the dataframe. In other words, the number of rows.
# df.head()     # displays the first 5 rows of the dataframe. df.head(7) will display the first 7
# df.tail()     # displays the last 5 rows of the dataframe. df.tail(7) will display the last 7
# df.describe()
# df.info()
# df.column.value_counts()
# ```
# ---
#
# **Sorting**
# ```python
# df.sort_values(by='column')                                          # Sort a df by column name.
# df.sort_values(by=['column1', 'column2'], ascending=[True, False])   # Sort multiple columns and specify the ordering
# ```
# ---
#
# **Filtering**
# ```python
# df.COLUMN                   # Filtering columns by attribute
# df['COLUMN']                # Filtering columns by label/name
# df[['COLUMN1', 'COLUMN2']]  # Filtering for multiple columns
# ```
#
# ```python
# df[df.c == value]                       # Conditional filtering
# df[(df.c >= value) & (df.d < value)]    # Conditional filtering where both conditions have to be true
# df[(df.c < value) | (df.d != value)]    # Conditional filtering where either condition is true
# ```
#
# ---
#
# **Missing Values**
# ```python
# df.column.isnull()          # Boolean mask to check for null/missing values in a column
# df.fillna(value)            # Method to fill missing cells with specified value
# ```
#
# ---
#
# **Groupby**
# ```python
# df.groupby('column')                  .size() .mean() .min() .max()
# df.groupby(['column1', 'column2'])    .agg(['min', 'max'])
# ```
#
# ---
#
# **Plotting**
# ```python
# df.plot(kind= , title= , x=, y= ,marker= , color=, figsize=)
# ```

# %% [markdown]
# ---
#
# # <span style="color: #20B2AA">Let Us Know When You're Done</span>
#
# <a href="https://twitter.com/intent/tweet?screen_name=bigdatau&text=Making%20Visualizations%20and%20Learning%20Python%20for%20Data%20Science%20with%20asad_ali_47.%20%23bdumeetup%20%23datascience%20http%3A%2F%2Fi.imgur.com%2Fur2o0ZU.png" target="_blank">
#         <img src="http://i.imgur.com/sUNC7ax.png" width=640></a>
#
# ---

# %% [markdown]
# # <span style="color: #20B2AA">Useful Links</span>
#
# http://bigdatauniversity.com/ - A wealth of knowledge - sign up and get involved!
#
# http://datascientistworkbench.com/ - The fastest way to get right into data science
#
# http://www.fivethirtyeight.com - political blog based on statistics. Also looked at Uber in NYC
#
# http://www.flowingdata.com - brilliant visuals and tutorials
#
# http://www.reddit.com/r/dataisbeautiful - some interesting original content on personal behaviour and social commentary.

# %% [markdown]
# # <span style="color: #20B2AA">Get in Touch</span>
#
# <h4>[LinkedIn](https://www.linkedin.com/in/asad-ali-082a613b)</h4>
#
# <h4>asad.b.ali@gmail.com</h4>
